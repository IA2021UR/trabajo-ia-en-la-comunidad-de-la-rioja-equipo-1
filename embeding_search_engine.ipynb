# %% [markdown]
# <a href="https://colab.research.google.com/github/IA2021UR/trabajo-ia-en-la-comunidad-de-la-rioja-equipo-1/blob/main/embeding_search_engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.Pasos Previos

# %% [markdown]
# Descargamos la lógica necesaria para montar el motor de búsqueda por hash

# %%
# !wget https://s3-us-west-2.amazonaws.com/static.pyimagesearch.com/image-hashing-search-engine/hashing-search-engine.zip
# !unzip -qq hashing-search-engine.zip
# %cd hashing-search-engine

# !pip install opencv-contrib-python
# !pip install vptree

# Resto de paquetes que utilizaremos en las practicas
from imutils import paths
import argparse
import pandas as pd
import time
import sys
import os
import tensorflow as tf
from tensorflow.keras.models import load_model
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pickle
import vptree
# Out:
# --2021-05-31 12:40:42--  https://s3-us-west-2.amazonaws.com/static.pyimagesearch.com/image-hashing-search-engine/hashing-search-engine.zip
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.235.0
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.235.0|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113505 (111K) [application/zip]
# Saving to: ‘hashing-search-engine.zip’
#
# hashing-search-engi 100%[===================>] 110.84K   457KB/s    in 0.2s
#
# 2021-05-31 12:40:43 (457 KB/s) - ‘hashing-search-engine.zip’ saved [113505/113505]
#
# /content/hashing-search-engine/hashing-search-engine/hashing-search-engine/hashing-search-engine
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-contrib-python) (1.19.5)
# Requirement already satisfied: vptree in /usr/local/lib/python3.7/dist-packages (1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from vptree) (1.19.5)

# %% [markdown]
# Descargamos los modelos para la detección de caras, que utilizamos en el cuaderno anterior

# %%
# !wget https://www.dropbox.com/s/uji1ufb009ic3m0/mobilenet_graph.pb?dl=0 -O mobilenet_graph.pb
# Leer mobilenet_graph.pb
with tf.io.gfile.GFile('mobilenet_graph.pb','rb') as f:
    graph_def = tf.compat.v1.GraphDef()
    graph_def.ParseFromString(f.read())

with tf.Graph().as_default() as mobilenet:
    tf.import_graph_def(graph_def,name='')
# Out:
# --2021-05-31 12:40:49--  https://www.dropbox.com/s/uji1ufb009ic3m0/mobilenet_graph.pb?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/uji1ufb009ic3m0/mobilenet_graph.pb [following]
# --2021-05-31 12:40:49--  https://www.dropbox.com/s/raw/uji1ufb009ic3m0/mobilenet_graph.pb
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf61b229c8e33eac39d0c7f6db5.dl.dropboxusercontent.com/cd/0/inline/BPhdi6GdqmwlCADZst3t5Zd9t33RcFURPbz9DaxkJTilZgp-sTBm6v92qMDQfAea8sNUi7SQ0X1lD9HR9D4IjUtfbcI6-iukztF1Uvl0mAMuu_cFe6p6qU8hP21r7y6m2CjpIiX9bfD3sy14U8DCtjQ1/file# [following]
# --2021-05-31 12:40:49--  https://ucf61b229c8e33eac39d0c7f6db5.dl.dropboxusercontent.com/cd/0/inline/BPhdi6GdqmwlCADZst3t5Zd9t33RcFURPbz9DaxkJTilZgp-sTBm6v92qMDQfAea8sNUi7SQ0X1lD9HR9D4IjUtfbcI6-iukztF1Uvl0mAMuu_cFe6p6qU8hP21r7y6m2CjpIiX9bfD3sy14U8DCtjQ1/file
# Resolving ucf61b229c8e33eac39d0c7f6db5.dl.dropboxusercontent.com (ucf61b229c8e33eac39d0c7f6db5.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8d5d847ac0dce48a80b3cbd9a3.dl.dropboxusercontent.com/cd/0/inline/BPigTKJzf5g0o1-cwzoBraxzhFkIHGElctR2eschUoqltel8uYXVerb90Wy30jDYKfKfLscaEfaBGXa5E2gfT3coL6mnuSR3q4SUhyBhk_-_Huri8WmZ4nn7vMIRdyoSWMVP52bX10lFCuci1HoI2ylo/file# [following]
# --2021-05-31 12:41:38--  https://uc8d5d847ac0dce48a80b3cbd9a3.dl.dropboxusercontent.com/cd/0/inline/BPigTKJzf5g0o1-cwzoBraxzhFkIHGElctR2eschUoqltel8uYXVerb90Wy30jDYKfKfLscaEfaBGXa5E2gfT3coL6mnuSR3q4SUhyBhk_-_Huri8WmZ4nn7vMIRdyoSWMVP52bX10lFCuci1HoI2ylo/file
# Resolving uc8d5d847ac0dce48a80b3cbd9a3.dl.dropboxusercontent.com (uc8d5d847ac0dce48a80b3cbd9a3.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc8d5d847ac0dce48a80b3cbd9a3.dl.dropboxusercontent.com (uc8d5d847ac0dce48a80b3cbd9a3.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17547739 (17M) [text/plain]
# Saving to: ‘EmbeddingsFotos.csv’
#
# EmbeddingsFotos.csv 100%[===================>]  16.73M  36.9MB/s    in 0.5s
#
# 2021-05-31 12:41:39 (36.9 MB/s) - ‘EmbeddingsFotos.csv’ saved [17547739/17547739]

# %% [markdown]
# # 2. Creación del dataset de búsqueda de caras para vptrees

# %% [markdown]
# Esta función está explicada en la anterior sección , obtiene de una imagen un vector(bboxes) que tiene todas las caras que se han podido detectar en la imagen

# %%
def detect_faces(image, score_threshold=0.7):
    global boxes, scores
    (imh, imw) = image.shape[:-1]
    img = np.expand_dims(image,axis=0)
    
    # Inicializar mobilenet
    sess = tf.compat.v1.Session(graph=mobilenet)
    image_tensor = mobilenet.get_tensor_by_name('image_tensor:0')
    boxes = mobilenet.get_tensor_by_name('detection_boxes:0')
    scores = mobilenet.get_tensor_by_name('detection_scores:0')
    
    # Predicción (detección)
    (boxes, scores) = sess.run([boxes, scores], feed_dict={image_tensor:img})
    
    # Reajustar tamaños boxes, scores
    boxes = np.squeeze(boxes,axis=0)
    scores = np.squeeze(scores,axis=0)
    
    # Depurar bounding boxes
    idx = np.where(scores>=score_threshold)[0]
    
    # Crear bounding boxes
    bboxes = []
    for index in idx:
        ymin, xmin, ymax, xmax = boxes[index,:]
        (left, right, top, bottom) = (xmin*imw, xmax*imw, ymin*imh, ymax*imh)
        left, right, top, bottom = int(left), int(right), int(top), int(bottom)
        bboxes.append([left,right,top,bottom])
        
    return bboxes

# %% [markdown]
# Esta función una vez obtenidas las caras las recorta

# %%
def extract_faces(image,bboxes,new_size=(160,160)):
    cropped_faces = []
    for box in bboxes:
        left, right, top, bottom = box
        face = image[top:bottom,left:right]
        cropped_faces.append(cv2.resize(face,dsize=new_size))
    return cropped_faces

# %% [markdown]
# Esta función utilizando la librería de tratamiento de imagen cv2 lee una imagen desde un directorio, es útil ya que nos permite leer el color en RGB , la segunda función nos muestra una figura de una imagen

# %%
from google.colab.patches import cv2_imshow
def load_image(DIR, NAME):
    return cv2.cvtColor(cv2.imread(f'{DIR}/{name}'), cv2.COLOR_BGR2RGB)

def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %% [markdown]
# Utilizaremos el fichero de embeddings para tratar de buscar aquellos similares

# %%
# #directorio de trabajo
# dir='/content/hashing-search-engine/2'
# maxImagenes=100
# cont=0
# listaCaras={}
# for name in os.listdir(dir):
#   if name.endswith('.jpg'):
#     if cont==maxImagenes:
#       break
#     print(f'   {name}')
#     # try:
#     image = load_image(dir,name)
#     bboxes=detect_faces(image)
#     if len(bboxes)>0:
      
#       faces = extract_faces(image,bboxes)
#       listaCaras[name]=faces

#   cont=cont+1

# %% [markdown]
# Ahora para cada imagen obtenida en el paso anterior guardamos su cara asociadas con el nº de cara de la siguiente forma:
# Imagen1.jpg
#
# <!-- Caras-> Imagen1_1.jpg, Imagen2_1.jpg-Imagen2_2.jpg -->

# %% [markdown]
# Una vez que ya disponemos de las imágenes de las caras utilizaremos las búsquedas con vptrees.

# %% [markdown]
# # 3 VPTrees y Hashing para la búsqueda de imágenes

# %% [markdown]
# La idea central de este notebook consiste en establecer una función embedding que marque de manera única a cada imagen , en función de la "proximidad" de hash entre las imágenes podremos encontrar aquellas imágenes con un hash similar.
# Las imágenes que vamos a comparar son las caras de nuestras imágenes.

# %% [markdown]
# ### Ahora implementaremos nuestro índice con los hashes

# %%
args = {
    "images": "3",  #input de imágenes de caras en las que buscaremos coincidencias
    "tree": "vptree.pickle",
    "hashes": "hashes.pickle"
}

# %%
df = pd.read_csv('EmbeddingsFotos.csv')
df.head()
# !wget https://www.dropbox.com/s/z0o1of3580smtwr/facenet_keras.h5?dl=0 -O facenet_keras.h5
facenet = load_model('facenet_keras.h5')
# Out:
# --2021-05-31 13:31:31--  https://www.dropbox.com/s/z0o1of3580smtwr/facenet_keras.h5?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/z0o1of3580smtwr/facenet_keras.h5 [following]
# --2021-05-31 13:31:31--  https://www.dropbox.com/s/raw/z0o1of3580smtwr/facenet_keras.h5
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc388eb4de17557609237f4ca1d8.dl.dropboxusercontent.com/cd/0/inline/BPhIupsEoSjHnwRvj_OUcDTVti6BxknX-TX87FQVGZ8LsU50JuEB3MDtuug4DbG0CDbjWcljE-Gm6vgFnmWuf3EyJz6nprRrQhgLFijZSIcC1FHlDjxSmtz36oR7IBeecpbyWuI4waML2CHXuuMm-6WO/file# [following]
# --2021-05-31 13:31:32--  https://uc388eb4de17557609237f4ca1d8.dl.dropboxusercontent.com/cd/0/inline/BPhIupsEoSjHnwRvj_OUcDTVti6BxknX-TX87FQVGZ8LsU50JuEB3MDtuug4DbG0CDbjWcljE-Gm6vgFnmWuf3EyJz6nprRrQhgLFijZSIcC1FHlDjxSmtz36oR7IBeecpbyWuI4waML2CHXuuMm-6WO/file
# Resolving uc388eb4de17557609237f4ca1d8.dl.dropboxusercontent.com (uc388eb4de17557609237f4ca1d8.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc388eb4de17557609237f4ca1d8.dl.dropboxusercontent.com (uc388eb4de17557609237f4ca1d8.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BPiQy5QkXGm8bplFhfOu9eW0O1gMYgGcwuggkK5lxmGMXFtfHU4fwC-GzAGaCqTdv6HT2irj46Jv8i2tYpxHgKk0zxf2wwJnaBaca4mbuCyzAaVb2mMn8piX4Ew_ZDdcZ6YbSy6N1ymUvxzf6LGxaHakgVCq4OGqdDOdylNRt8JF1vddCGu5XgdQ0YAKL_JVNCaHcxB4A4yQF9BKjS064Ol4qSE1UaWTGpxG2A7axW04g-qmcQfGyTIPtRhL-4Ij676Z0FTmFuItRmZ0ZtxL9kJlZaOJ_H9qICpn6zLrdR3iJTTO8FnaYspVY0aOpQuC3JWcosYc2li1EFs40RkIy-FJKJ5LEXLqWxbmFGPdMAraywmqf0idxaPCJazs7ePEVSs/file [following]
# --2021-05-31 13:31:32--  https://uc388eb4de17557609237f4ca1d8.dl.dropboxusercontent.com/cd/0/inline2/BPiQy5QkXGm8bplFhfOu9eW0O1gMYgGcwuggkK5lxmGMXFtfHU4fwC-GzAGaCqTdv6HT2irj46Jv8i2tYpxHgKk0zxf2wwJnaBaca4mbuCyzAaVb2mMn8piX4Ew_ZDdcZ6YbSy6N1ymUvxzf6LGxaHakgVCq4OGqdDOdylNRt8JF1vddCGu5XgdQ0YAKL_JVNCaHcxB4A4yQF9BKjS064Ol4qSE1UaWTGpxG2A7axW04g-qmcQfGyTIPtRhL-4Ij676Z0FTmFuItRmZ0ZtxL9kJlZaOJ_H9qICpn6zLrdR3iJTTO8FnaYspVY0aOpQuC3JWcosYc2li1EFs40RkIy-FJKJ5LEXLqWxbmFGPdMAraywmqf0idxaPCJazs7ePEVSs/file
# Reusing existing connection to uc388eb4de17557609237f4ca1d8.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92397640 (88M) [application/octet-stream]
# Saving to: ‘facenet_keras.h5’
#
# facenet_keras.h5    100%[===================>]  88.12M  55.8MB/s    in 1.6s
#
# 2021-05-31 13:31:34 (55.8 MB/s) - ‘facenet_keras.h5’ saved [92397640/92397640]
#
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
known_embeddings = []

print('Procesando rostros conocidos...')
for name in os.listdir('/content/hashing-search-engine/queries/'):
    if name.endswith('.jpg'):
        # print(f'   {name}')
        image = load_image('/content/hashing-search-engine/queries/',name)
        bboxes = detect_faces(image)
        if len(bboxes)>0:
          print(name)
          face = extract_faces(image,bboxes)
          for f in faces:
            known_embeddings.append(compute_embedding(facenet,f))
# Out:
# Procesando rostros conocidos...
# prueba.jpg

# %%
embeddingsModelo = df['Embedding']
nombreFoto = df['NombreFoto']
print(nombreFoto[0:5])
print(embeddingsModelo[0:5])
# Out:
# 0    462220.jpg 0
# 1    462220.jpg 1
# 2     44569.jpg 0
# 3     44569.jpg 1
# 4     44569.jpg 2
# Name: NombreFoto, dtype: object
# 0    [[ 2.3611324   0.7700528   1.5315906  -1.38208...
# 1    [[-0.18996963  0.47556552  0.3286136   1.53095...
# 2    [[-0.67055297 -0.4772751  -0.05659456  0.97165...
# 3    [[-8.7787104e-01  1.4074993e+00 -9.2881995e-01...
# 4    [[ 0.55190855  0.47906682 -1.9257076  -0.58596...
# Name: Embedding, dtype: object

# %%
listaEmbedings=[]
for caraEmb in embeddingsModelo:  
  lista=caraEmb.replace('[','').replace(']','').split(' ')
  aux=[]
  for elem in lista:
    if elem != '':
      aux.append(float(elem))
  aux2=[]
  aux2.append(aux) 
     
  listaEmbedings.append(np.array(aux2, dtype='f')[0])

# %%
points = np.random.randn(20000, 10)
print(points[0])
print('aaaaaaaaaaaaaaaaaa')
print(listaEmbedings[0])
# Out:
# [ 0.37950708 -1.11633593  0.6792687  -1.0172035   0.10036278  0.69330913
#   0.94834642 -1.91666903  0.46560671 -0.14559642]
# aaaaaaaaaaaaaaaaaa
# [ 2.3611324   0.7700528   1.5315906  -1.3820868  -1.1635649   1.3472668
#   0.87286216  1.2065074   0.44725147  0.50114185  0.37825572 -1.3856409
#  -1.8207488   2.366099   -1.0517621   0.19684696 -1.6895274  -0.7217798
#  -1.4647588  -0.03834521 -0.99122274 -0.07428449  0.5706365   1.6811378
#   0.43134415 -1.3027197   0.6371535  -1.6886992   1.5508138   2.351854
#  -0.09599635 -0.23541917  0.10919712  0.26031098 -1.2777082  -0.85371566
#  -0.8466384   0.3355232  -1.9908612   0.65470695  0.54386455 -1.2465221
#   0.67928195  0.25521836 -0.5888226  -2.0863295  -0.67774767  0.6541424
#  -1.2540616  -0.39387453  0.21047516  0.6548834   1.5472864  -0.5407878
#  -1.8158253   0.8265521   0.2965009  -0.03269419 -0.44857696  0.19229105
#  -0.01182378  1.7094091   0.84046054  3.5821512  -0.1496942   1.0423487
#  -0.2113325   1.2037497   0.0704241   0.88144886  0.4603742  -0.24757068
#   2.7278593  -0.01819924  0.68553483 -0.62064356 -0.03240651  0.1329515
#  -1.118797   -0.6598887  -0.15346058  0.1150578  -1.1539365   0.19645973
#   1.7287052  -1.5711869  -0.16005427 -2.848127    1.1052141  -1.1326364
#  -0.42764184 -0.24037911  0.6021553   0.5624756   0.5625597   1.1096517
#  -0.53013414 -0.32481435 -1.2221737  -1.5735592  -0.8318649   0.8762131
#   0.428477    0.6860691   0.16867134 -0.11697178 -1.110863   -0.5416577
#  -0.412487    0.603508    1.0054862   1.3279824   0.5817814   0.7778604
#  -1.6993539   0.7154578  -0.0550987  -0.8597842  -2.4078326   0.14821266
#   1.2972195  -0.27478924  0.11232242 -1.1527025  -0.9318183   0.28368658
#  -0.36497682  0.07599658]

# %%
def compare_faces(embs_ref, emb_desc, umbral=10):
    distancias = []
    for emb_ref in embs_ref:
        distancias.append(np.linalg.norm(emb_ref-emb_desc))
    distancias = np.array(distancias)
    return distancias, list(distancias<=umbral)

# %%
# Cons
print("Construcción del vptrees con el dccionario de hashing")
# points = list(hashes.keys())
points= listaEmbedings
# for p in points:
#   print(p)
#   print('heello')
tree = vptree.VPTree(points, compare_faces2)
# Out:
# Construcción del vptrees con el dccionario de hashing

# %%
def compare_faces2(a, b, umbral=10):
    return np.linalg.norm(a-b)

# %%
ls
# Out:
# 2/     EmbeddingsFotos.csv  index_images.py     pyimagesearch/  vptree.pickle
# 2.zip  facenet_keras.h5     mobilenet_graph.pb  queries/
# 3/     hashes.pickle        prueba.jpg          search.py

# %%
distancia,emb=tree.get_nearest_neighbor(target)


emb
# # Query n-points.
# tree.get_n_nearest_neighbors(target, 10)
cont=0
listAux=[]
for caraEmb in embeddingsModelo:  
  lista=caraEmb.replace('[','').replace(']','').split(' ')
  aux=[]
  for elem in lista:
    if elem != '':
      aux.append(float(elem))
  aux2=[]
  aux2.append(aux)    
  fin=[np.array(aux2, dtype='f')]

  if emb_iguales(emb,fin[0][0]):
  

  # if emb==fin:

  
    nomF=nombreFoto[cont].split(' ')[0]
    #if not nomF in listAux:
     # listAux.append(nomF)
      #image = load_image('2', nomF)
      #mostrarImagen(image)
    print(nomF)
    image = cv2.imread("2/"+nomF)
    mostrarImagen(image)

  cont=cont+1;
    

print(cont)
# Out:
# 473680.jpg
# 10290

# %%
def emb_iguales(lista1,lista2):
  for indice, (item1, item2) in enumerate(zip(lista1, lista2)):
    if item1 != item2:
      return False
  return True

# %%
distancia,emb=tree.get_all_in_range(target, 15)




# # Query n-points.
# tree.get_n_nearest_neighbors(target, 10)
cont=0
listAux=[]
for caraEmb in embeddingsModelo:  
  lista=caraEmb.replace('[','').replace(']','').split(' ')
  aux=[]
  for elem in lista:
    if elem != '':
      aux.append(float(elem))
  aux2=[]
  aux2.append(aux)    
  fin=[np.array(aux2, dtype='f')]

  for e in emb:
    if emb_iguales(e,fin[0][0]):
  

  # if emb==fin:

  
      nomF=nombreFoto[cont].split(' ')[0]
      #if not nomF in listAux:
      # listAux.append(nomF)
        #image = load_image('2', nomF)
        #mostrarImagen(image)
      print(nomF)
      image = cv2.imread("2/"+nomF)
      mostrarImagen(image)

    cont=cont+1;
    

print(cont)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-251-961cf2f25472> in <module>()
#       1
# ----> 2 distancia,emb=tree.get_all_in_range(target, 15)
#       3
#       4
#       5
#
# ValueError: too many values to unpack (expected 2)

# %%
list(emb)

# %%
def mostrarImagen(image):
    if len(image.shape)==3:
        img2 = image[:,:,::-1]
        plt.imshow(img2)
        plt.show()

# %%
# serialize the VP-Tree to disk
print("Ajustando VP-Tree...")
f = open(args["tree"], "wb")
f.write(pickle.dumps(tree))
# f.close()

# # serialize the hashes to dictionary
print("[INFO] Gestionando los hashes...")
# f = open(args["hashes"], "wb")
# f.write(pickle.dumps(hashes))
# f.close()
# Out:
# Ajustando VP-Tree...
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-221-dbf9bc2db8db> in <module>()
#       2 print("Ajustando VP-Tree...")
#       3 f = open(args["tree"], "wb")
# ----> 4 f.write(pickle.dumps(tree))
#       5 # f.close()
#       6
#
# PicklingError: Can't pickle <function compare_faces2 at 0x7fb64a34f950>: it's not the same object as __main__.compare_faces2

# %% [markdown]
# ### Implementing our image hash searching script

# %% [markdown]
# **Busqueda de una cara** , nota por simplicidad utilizaremos fotos con una sola cara .

# %%
# !wget https://www.dropbox.com/s/jc493jeqq2wshuy/conchi.jpg?dl=0 -O prueba.jpg
# Out:
# --2021-05-31 12:41:51--  https://www.dropbox.com/s/jc493jeqq2wshuy/conchi.jpg?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/jc493jeqq2wshuy/conchi.jpg [following]
# --2021-05-31 12:41:51--  https://www.dropbox.com/s/raw/jc493jeqq2wshuy/conchi.jpg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce5b1836e4677e5c394bda942e2.dl.dropboxusercontent.com/cd/0/inline/BPiVbPEpeSq5M6x6ErdDZ9VMv10Z34cINYOYqVBhLD4DiiN6mxSvbbwNLeBHWQnWA4EP-CdkxNSiRIUYcWLDlHsFvGUveMDaR1k3B-b6dIOFAYsvnfVxoGS4c2aaWsBMqoWMnBERi0w10vjcFeb4Z7xm/file# [following]
# --2021-05-31 12:41:51--  https://uce5b1836e4677e5c394bda942e2.dl.dropboxusercontent.com/cd/0/inline/BPiVbPEpeSq5M6x6ErdDZ9VMv10Z34cINYOYqVBhLD4DiiN6mxSvbbwNLeBHWQnWA4EP-CdkxNSiRIUYcWLDlHsFvGUveMDaR1k3B-b6dIOFAYsvnfVxoGS4c2aaWsBMqoWMnBERi0w10vjcFeb4Z7xm/file
# Resolving uce5b1836e4677e5c394bda942e2.dl.dropboxusercontent.com (uce5b1836e4677e5c394bda942e2.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uce5b1836e4677e5c394bda942e2.dl.dropboxusercontent.com (uce5b1836e4677e5c394bda942e2.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63203 (62K) [image/jpeg]
# Saving to: ‘prueba.jpg’
#
# prueba.jpg          100%[===================>]  61.72K  --.-KB/s    in 0.03s
#
# 2021-05-31 12:41:52 (1.74 MB/s) - ‘prueba.jpg’ saved [63203/63203]

# %%
ls
# Out:
# 2/     EmbeddingsFotos.csv  index_images.py     pyimagesearch/  vptree.pickle
# 2.zip  facenet_keras.h5     mobilenet_graph.pb  queries/
# 3/     hashes.pickle        prueba.jpg          search.py

# %%
#1.leemos la foto y extraemos la cara
img=cv2.cvtColor(cv2.imread('/content/hashing-search-engine/queries/prueba.jpg'), cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(img)
plt.title('Imagen entera')

#2 Detectamos la cara y la extraemos
bboxes=detect_faces(img)
cara= extract_faces(img,bboxes)
plt.figure()
plt.title('cara recortada')
plt.imshow(cara[0])

cv2.imwrite('queries/prueba.jpg', cv2.cvtColor(cara[0], cv2.COLOR_RGB2BGR))    

target=compute_embedding(facenet,cara[0])
target=list(target[0])
print('Embedding:')
print(target)
# Out:
# Embedding:
# [0.46163118, 1.2827555, 2.0616877, -0.6365244, 0.545948, -0.1488898, -0.043988742, 0.60198027, 0.22426867, -0.8810258, -0.034480464, 0.42573512, 1.2733778, 1.3547221, -0.462155, -1.6712674, 0.39588773, -0.7784619, 0.87781775, -0.17642128, -1.4390091, 0.16761951, -0.70601463, 0.8348232, -0.50916636, -0.13232526, -0.300391, 1.0891649, 0.9098565, 0.2001862, -1.1476884, -0.8619923, 0.9173147, -0.76932603, -0.6081056, 0.86677134, 0.20640522, -0.064809956, -1.3798726, 1.4493724, 1.7715548, 0.52616966, -0.33045226, 0.85914445, -2.2566316, 0.35756692, -1.1939142, -0.38833457, 0.36375785, -0.32485488, 2.2755663, 2.0086493, 0.65205735, -3.3605607, -0.3839988, 1.9588538, 0.581668, -0.30730498, 0.65510637, -0.40517816, 0.60412306, -1.2922708, 0.98231685, 1.7684314, -0.8914479, 0.009155557, -0.11812661, -0.28792945, 2.0911756, -0.47873768, 0.4845362, -0.84723794, 0.6003987, -0.5795398, 1.3744156, 0.7521509, 0.8756281, 0.84155405, -2.0076556, -0.103510335, -0.37200466, 1.8756262, 0.17378631, -0.016864149, 0.41877356, 0.4280348, 0.4631924, -0.35417897, -0.8282422, 1.4158089, -1.4801005, 0.40935642, 1.3405344, 1.4781486, 0.23243116, -0.72136724, 0.5254087, -1.5769523, -0.40294084, 0.59350103, -0.74986875, 1.9657075, 1.2319112, -0.16848904, -1.9701351, -0.10518191, -0.53655237, 0.715323, -0.32628292, -0.970595, 0.4255706, 1.5989027, -0.94700396, 1.8615183, 1.0658034, 1.4407225, 1.9121196, -0.76495785, -0.027725853, 0.18111551, 0.011099722, -0.064998604, -0.6303028, -2.6789348, -1.1119653, 0.85758513, -0.39879027, 0.57718134]

# %%
# construct the argument parser and parse the arguments

args = {
    "tree": "vptree.pickle",
    "hashes": "hashes.pickle",
    "query": "queries/face.jpg", #tomaremos las imágenes desde esta carpeta
    "distance": 20 #distancia entre los hashes
}

# %%
# Cargamos el modelo de VP-Tree y el diccionario de hashes
print("[INFO] loading VP-Tree and hashes...")
tree = pickle.loads(open(args["tree"], "rb").read())
hashes = pickle.loads(open(args["hashes"], "rb").read())

# load the input query image
# image = cv2.imread('/content/hashing-search-engine/queries/a.jpg')
plt.imshow(cara[0])
plt.title('cara a buscar')
plt.show()

# compute the hash for the query image, then convert it
queryHash = compute_embedding(facenet,image)
queryHash = list(queryHash[0])
print('HASH imagen:')
print(queryHash)
# Out:
# [INFO] loading VP-Tree and hashes...
# HASH imagen:
# [0.16134283, 0.51407313, 1.8663944, -0.8553416, 0.6919369, -0.3965725, 0.35541284, 0.7623719, -0.44322038, -0.5205182, -0.03921339, 0.10254196, 1.7049044, 0.87587, 0.17314668, -1.4090931, -0.16938967, -0.52545816, 0.77501947, -0.1941935, -0.9072455, -0.08256394, -0.48993742, 0.55523264, -0.671509, 0.24352679, -0.81088805, 1.3437624, 0.43852204, 0.04925227, -0.7736052, -0.5709414, 0.75524026, -0.7426638, 0.01637668, 0.569197, -0.25602922, 0.08214224, -0.9316401, 1.5560554, 1.5429949, 0.9965506, 0.25368094, 0.28000158, -2.2263064, 0.21225923, -0.9945447, -0.096021235, 0.2516453, -0.5026752, 1.8961135, 2.298741, 0.340751, -2.9992447, 0.07374208, 1.0576692, 0.29719347, 0.3949977, 0.10797561, -0.6448998, 0.9727978, -1.7436875, 0.7821965, 1.3283966, -1.2481228, -0.42602903, -0.11157512, -0.18542913, 2.1791782, -0.21229595, 0.8107609, -0.9729034, 0.34961513, -0.7201087, 1.1917182, 0.6654581, 0.52048063, 1.0261675, -1.9752225, 0.19553597, 0.030664086, 1.5773753, 0.14749198, -0.23752992, -0.1977933, 0.6686799, 0.1607692, -0.44605863, -0.7707803, 1.2044785, -1.264905, 0.07345664, 1.0410407, 2.0554516, 0.32565424, -0.43227118, -0.031726666, -1.2760758, -0.287288, 0.5674256, -0.4718365, 1.6020336, 0.8679, -0.2253456, -2.0740483, -0.3038386, -0.37579054, 0.264627, -0.4189053, -0.31675878, 0.037852623, 1.639583, -0.7680316, 1.4869025, 1.2086102, 1.1970575, 1.6123176, -1.4506092, -0.36746943, -0.23148991, -0.22712179, 0.15690911, -0.72168994, -2.569701, -1.2041271, 0.83902085, -0.5275172, 0.45641106]

# %%
queryHash
# Out:
# [0.16134283,
#  0.51407313,
#  1.8663944,
#  -0.8553416,
#  0.6919369,
#  -0.3965725,
#  0.35541284,
#  0.7623719,
#  -0.44322038,
#  -0.5205182,
#  -0.03921339,
#  0.10254196,
#  1.7049044,
#  0.87587,
#  0.17314668,
#  -1.4090931,
#  -0.16938967,
#  -0.52545816,
#  0.77501947,
#  -0.1941935,
#  -0.9072455,
#  -0.08256394,
#  -0.48993742,
#  0.55523264,
#  -0.671509,
#  0.24352679,
#  -0.81088805,
#  1.3437624,
#  0.43852204,
#  0.04925227,
#  -0.7736052,
#  -0.5709414,
#  0.75524026,
#  -0.7426638,
#  0.01637668,
#  0.569197,
#  -0.25602922,
#  0.08214224,
#  -0.9316401,
#  1.5560554,
#  1.5429949,
#  0.9965506,
#  0.25368094,
#  0.28000158,
#  -2.2263064,
#  0.21225923,
#  -0.9945447,
#  -0.096021235,
#  0.2516453,
#  -0.5026752,
#  1.8961135,
#  2.298741,
#  0.340751,
#  -2.9992447,
#  0.07374208,
#  1.0576692,
#  0.29719347,
#  0.3949977,
#  0.10797561,
#  -0.6448998,
#  0.9727978,
#  -1.7436875,
#  0.7821965,
#  1.3283966,
#  -1.2481228,
#  -0.42602903,
#  -0.11157512,
#  -0.18542913,
#  2.1791782,
#  -0.21229595,
#  0.8107609,
#  -0.9729034,
#  0.34961513,
#  -0.7201087,
#  1.1917182,
#  0.6654581,
#  0.52048063,
#  1.0261675,
#  -1.9752225,
#  0.19553597,
#  0.030664086,
#  1.5773753,
#  0.14749198,
#  -0.23752992,
#  -0.1977933,
#  0.6686799,
#  0.1607692,
#  -0.44605863,
#  -0.7707803,
#  1.2044785,
#  -1.264905,
#  0.07345664,
#  1.0410407,
#  2.0554516,
#  0.32565424,
#  -0.43227118,
#  -0.031726666,
#  -1.2760758,
#  -0.287288,
#  0.5674256,
#  -0.4718365,
#  1.6020336,
#  0.8679,
#  -0.2253456,
#  -2.0740483,
#  -0.3038386,
#  -0.37579054,
#  0.264627,
#  -0.4189053,
#  -0.31675878,
#  0.037852623,
#  1.639583,
#  -0.7680316,
#  1.4869025,
#  1.2086102,
#  1.1970575,
#  1.6123176,
#  -1.4506092,
#  -0.36746943,
#  -0.23148991,
#  -0.22712179,
#  0.15690911,
#  -0.72168994,
#  -2.569701,
#  -1.2041271,
#  0.83902085,
#  -0.5275172,
#  0.45641106]

# %%
# Buscamos
print("[INFO] performing search...")
start = time.time()
results = tree.get_all_in_range(queryHash, args["distance"])
results = sorted(results)
end = time.time()
print("[INFO] search took {} seconds".format(end - start))

# %%
# loop over the results
for (d, h) in results:
	# grab all image paths in our dataset with the same hash
	resultPaths = hashes.get(h, [])
	print("[INFO] {} total image(s) with d: {}, h: {}".format(
		len(resultPaths), d, h))

	# loop over the result paths
	for resultPath in resultPaths:
		# load the result image and display it to our screen
		result = cv2.imread(resultPath)
		plt_imshow("Result", result)

# %% [markdown]
# Como conclusion comentar que esta forma de identificar "matches" entre caras no es muy efectivo ya que una misma persona en función de carácteristicas de la foto : ángulo , luz , contrastes etc puede ser muy diferente.
# No por tener dos imágenes un hash parecido tendrán que ser del mismo objeto.
# De hecho caras de la misma persona pueden tener hashes completamente diferentes.
